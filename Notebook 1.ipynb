# %%
import pandas as pd
import numpy as np

# Generate random data with 2 columns and 10 rows
df = pd.DataFrame({
    'column_1': np.random.randint(1, 100, size=10),
    'column_2': np.random.uniform(0, 1, size=10)
})

display(df)
